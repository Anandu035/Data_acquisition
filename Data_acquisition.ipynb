# %%
import pandas as pd

# %% [markdown]
# #  1. Find a Dataset:
# covid kerala data set found in kaggle

# %% [markdown]
# ## 2. Load the Dataset:

# %%
df= pd.read_csv('/content/covid_data_kerala.csv')

# %% [markdown]
# ## 3. Perform Initial Exploration:

# %%
df.head()
# Out:
#          Date  Confirmed  Recovered  Deceased
# 0  2020-01-31        0.0        NaN       0.0
# 1  2020-02-01        0.0        NaN       0.0
# 2  2020-02-02        1.0        NaN       0.0
# 3  2020-02-03        1.0        NaN       0.0
# 4  2020-02-04        0.0        NaN       0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 841 entries, 0 to 840
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       841 non-null    object
#  1   Confirmed  841 non-null    float64
#  2   Recovered  785 non-null    float64
#  3   Deceased   841 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 26.4+ KB

# %%
df.describe()
# Out:
#           Confirmed     Recovered     Deceased
# count    841.000000    785.000000   841.000000
# mean    7788.395957   8251.403822    82.656361
# std    10295.657109  10575.230709   126.911451
# min        0.000000      0.000000     0.000000
# 25%      438.000000    915.000000     8.000000
# 50%     4470.000000   4749.000000    25.000000
# 75%     9445.000000  11067.000000   122.000000
# max    55475.000000  99651.000000  1205.000000

# %% [markdown]
#  Q1:What is the size of the dataset?

# %%
df.shape
# Out:
# (841, 4)

# %% [markdown]
#  Q2:Whatare the data types of each column?

# %%
df.dtypes
# Out:
# Date          object
# Confirmed    float64
# Recovered    float64
# Deceased     float64
# dtype: object

# %% [markdown]
# Q3:Are there any missing values in the dataset? If so, which columns have
#  missing values and how many?

# %%
nullcolumn=df.isnull().sum()
nullcolumn=nullcolumn[nullcolumn>0]
nullcolumn
# Out:
# Recovered    56
# dtype: int64

# %% [markdown]
# Q4:Whatare the unique values in a categorical column of your choice? How
#  many unique values are there?

# %%
df['Confirmed'].unique()
# Out:
# array([0.0000e+00, 1.0000e+00, 6.0000e+00, 8.0000e+00, 2.0000e+00,
#        3.0000e+00, 1.2000e+01, 1.5000e+01, 2.8000e+01, 1.4000e+01,
#        9.0000e+00, 1.9000e+01, 3.9000e+01, 2.0000e+01, 3.2000e+01,
#        7.0000e+00, 2.4000e+01, 2.1000e+01, 1.1000e+01, 1.3000e+01,
#        1.0000e+01, 4.0000e+00, 5.0000e+00, 2.6000e+01, 1.6000e+01,
#        2.9000e+01, 4.2000e+01, 6.2000e+01, 5.3000e+01, 4.9000e+01,
#        6.7000e+01, 4.0000e+01, 8.5000e+01, 5.8000e+01, 6.1000e+01,
#        5.7000e+01, 8.6000e+01, 8.2000e+01, 9.4000e+01, 1.1100e+02,
#        1.0800e+02, 1.0700e+02, 9.1000e+01, 6.5000e+01, 8.3000e+01,
#        7.8000e+01, 5.4000e+01, 7.9000e+01, 7.5000e+01, 9.7000e+01,
#        1.1800e+02, 1.2700e+02, 1.3300e+02, 1.3800e+02, 1.4100e+02,
#        1.5200e+02, 1.2300e+02, 1.5000e+02, 1.9500e+02, 1.2200e+02,
#        1.3100e+02, 1.5100e+02, 1.6000e+02, 2.1100e+02, 2.4000e+02,
#        2.2500e+02, 1.9300e+02, 2.7200e+02, 3.0100e+02, 3.3900e+02,
# ...

# %%
df['Confirmed'].nunique()
# Out:
# 728

# %% [markdown]
#  Q5:Foranumerical column of your choice, calculate the mean, median, and
#  standard deviation.

# %%
df['Confirmed'].mean()
# Out:
# 7788.395957193817

# %%
df["Confirmed"].median()
# Out:
# 4470.0

# %%
df['Confirmed'].std()
# Out:
# 10295.657108885549

# %% [markdown]
# Q6: Identify any potential outliers in a numerical column of your choice. Explain
#  your approach.

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#            Date  Confirmed  Recovered  Deceased
# 0    2020-01-31        0.0        NaN       0.0
# 1    2020-02-01        0.0        NaN       0.0
# 2    2020-02-02        1.0        NaN       0.0
# 3    2020-02-03        1.0        NaN       0.0
# 4    2020-02-04        0.0        NaN       0.0
# ..          ...        ...        ...       ...
# 836  2022-05-16      324.0      364.0      31.0
# 837  2022-05-17      596.0      366.0       6.0
# 838  2022-05-18      501.0      460.0      17.0
# 839  2022-05-19      556.0      362.0      23.0
# 840  2022-05-20      558.0      446.0      63.0
#
# [841 rows x 4 columns]

# %%
df['Date'] = pd.to_datetime(df['Date']) #date waas in string dtype ,so it is converted to date format

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Confirmed           float64
# Recovered           float64
# Deceased            float64
# dtype: object

# %%
df=df.sort_values(by='Date')  #sorted data based on date

# %%
df
# Out:
#           Date  Confirmed  Recovered  Deceased
# 0   2020-01-31        0.0        NaN       0.0
# 1   2020-02-01        0.0        NaN       0.0
# 2   2020-02-02        1.0        NaN       0.0
# 3   2020-02-03        1.0        NaN       0.0
# 4   2020-02-04        0.0        NaN       0.0
# ..         ...        ...        ...       ...
# 836 2022-05-16      324.0      364.0      31.0
# 837 2022-05-17      596.0      366.0       6.0
# 838 2022-05-18      501.0      460.0      17.0
# 839 2022-05-19      556.0      362.0      23.0
# 840 2022-05-20      558.0      446.0      63.0
#
# [841 rows x 4 columns]

# %%
df.plot(x='Date',y='Confirmed')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(x='Date',y='Recovered')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(x='Date',y='Deceased')
# Out:
# <Axes: xlabel='Date'>

# %%
df.boxplot('Recovered')
# Out:
# <Axes: >

# %% [markdown]
# recovered cases of 100000 could be a outlier

# %% [markdown]
# Q7:Find the correlation between numerical columns and discuss any interesting
#  relationships.

# %%
df.corr()
# Out:
#                Date  Confirmed  Recovered  Deceased
# Date       1.000000   0.354381   0.324458  0.546776
# Confirmed  0.354381   1.000000   0.813598  0.443821
# Recovered  0.324458   0.813598   1.000000  0.514663
# Deceased   0.546776   0.443821   0.514663  1.000000

# %% [markdown]
# # INSIGHT
# confirmed and recovered covid cases have a positive correlation

# %%
plt.scatter(df['Confirmed'],df['Recovered'])
plt.xlabel('Confirmed')
plt.ylabel('Recovered')
plt.title('Confirmed vs Recovered')
plt.show()

# %% [markdown]
# Q8)Groupthe data by a categorical column and compute the aggregate statistics
#  (e.g., mean, sum) for a numerical column.

# %%
df.groupby('Date').sum()
# Out:
#             Confirmed  Recovered  Deceased
# Date
# 2020-01-31        0.0        0.0       0.0
# 2020-02-01        0.0        0.0       0.0
# 2020-02-02        1.0        0.0       0.0
# 2020-02-03        1.0        0.0       0.0
# 2020-02-04        0.0        0.0       0.0
# ...               ...        ...       ...
# 2022-05-16      324.0      364.0      31.0
# 2022-05-17      596.0      366.0       6.0
# 2022-05-18      501.0      460.0      17.0
# 2022-05-19      556.0      362.0      23.0
# 2022-05-20      558.0      446.0      63.0
#
# [841 rows x 3 columns]

# %%
df.groupby('Date').mean()
# Out:
#             Confirmed  Recovered  Deceased
# Date
# 2020-01-31        0.0        NaN       0.0
# 2020-02-01        0.0        NaN       0.0
# 2020-02-02        1.0        NaN       0.0
# 2020-02-03        1.0        NaN       0.0
# 2020-02-04        0.0        NaN       0.0
# ...               ...        ...       ...
# 2022-05-16      324.0      364.0      31.0
# 2022-05-17      596.0      366.0       6.0
# 2022-05-18      501.0      460.0      17.0
# 2022-05-19      556.0      362.0      23.0
# 2022-05-20      558.0      446.0      63.0
#
# [841 rows x 3 columns]

# %% [markdown]
# Q9::Based on your analysis, provide a brief summary of any insights or patterns
#  you discovered in the dataset.

# %% [markdown]
# **confirmed cases** and **recovered cases** shows same trend till JULY after that though the relation was positive there was a decline in recovered cases.
# During OCT there is a hike in death rate though with falling **recovery rates**.
# From FEB 2022,**covid cases**,**death cases** where at its peak.**Recovered cases** where also in trend with covid cases.
# After FEB **covid cases**,**recovery** and **death cases** where falling.
